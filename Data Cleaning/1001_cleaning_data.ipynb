# %% [markdown]
# # Data Cleaning
# -------------

# %% [markdown]
# We are going to clean and merge three datasets:
#  <br>raw_rawg.csv----  Key data: metacritic, rating, playtime
#  <br>vgsales.csv----  Key data: sales
#  <br>steam.csv----   Key data: price

# %%
import pandas as pd
import re
import numpy as np
from sklearn.experimental import enable_iterative_imputer 
from sklearn.impute import IterativeImputer

pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1. Merge the first two datasets

# %%
df_rawg = pd.read_csv("raw_rawg.csv")     
df_sales = pd.read_csv("vgsales.csv")

# %%
df_rawg.head()
# Out:
#                         name    released  \
# 0                  Half-Life  1998-11-19
# 1                    Fallout  1997-09-30
# 2  Half-Life: Opposing Force  1999-11-19
# 3     Resident Evil 2 (1998)  1998-01-21
# 4      Team Fortress Classic  1999-04-01
#
#                                            platforms  metacritic  rating  \
# 0  ['PC', 'macOS', 'Linux', 'PlayStation 2', 'Dre...        96.0    4.37
# 1      ['PC', 'macOS', 'Linux', 'Classic Macintosh']         NaN    4.20
# 2                           ['PC', 'macOS', 'Linux']         NaN    3.85
# 3  ['PC', 'PlayStation', 'GameCube', 'Nintendo 64...        90.0    4.32
# 4                           ['PC', 'macOS', 'Linux']         NaN    2.92
#
#    ratings_count  playtime                                               tags  \
# 0           2353         3  ['Singleplayer', 'Для одного игрока', 'Экшен',...
# 1           1199         1  ['Singleplayer', 'Для одного игрока', 'Приключ...
# 2            734         3  ['Singleplayer', 'Для одного игрока', 'Экшен',...
# 3            909        13  ['Singleplayer', 'Atmospheric', 'Great Soundtr...
# 4            382         1  ['Экшен', 'Приключение', 'Multiplayer', 'Для н...
#
#                   genres
# 0  ['Shooter', 'Action']
# 1                ['RPG']
# 2  ['Shooter', 'Action']
# 3             ['Action']
# 4             ['Action']

# %%
df_rawg.shape
# Out:
# (53607, 9)

# %%
df_sales.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df_sales.shape
# Out:
# (16598, 11)

# %%
df_sales.rename(columns={"Name": "name"}, inplace=True)

# %% [markdown]
# **Define a clean_title function to create a clean name for each game. Then, we'll merge the two datasets on the clean_title.**

# %%
def clean_title(title):
    if pd.isnull(title):
        return ""
    # Convert to lowercase
    title = title.lower()
    # Remove punctuation or special characters
    title = re.sub(r"[^\w\s]", "", title)
    # Trim whitespace
    title = title.strip()
    return title

df_rawg["clean_name"] = df_rawg["name"].apply(clean_title)
df_sales["clean_name"] = df_sales["name"].apply(clean_title)

# %%
df_merged = pd.merge(
    df_rawg, 
    df_sales, 
    on="clean_name",    
    how="inner"         # inner join
)

# %%
print("Merged Dataset shape:", df_merged.shape)
# df_merged.to_csv("merged_data.csv", index=False)
# Out:
# Merged Dataset shape: (10227, 21)

# %%
df_merged.drop(columns=['platforms', 'Year','genres', 'Rank', 'name_y'], inplace=True)
df_merged.head(10)
# Out:
#                     name_x    released  metacritic  rating  ratings_count  \
# 0                Half-Life  1998-11-19        96.0    4.37           2353
# 1                Half-Life  1998-11-19        96.0    4.37           2353
# 2  Oddworld: Abe's Oddysee  1997-09-19        85.0    3.53            555
# 3            Resident Evil  1996-03-22        91.0    4.18            788
# 4            Resident Evil  1996-03-22        91.0    4.18            788
# 5            Resident Evil  1996-03-22        91.0    4.18            788
# 6       X-COM: UFO Defense  1993-12-30         NaN    3.65            275
# 7                    Quake  1996-06-22        94.0    4.25            474
# 8           Tomb Raider II  1997-10-31        69.0    3.74            298
# 9           Tomb Raider II  1997-10-31        69.0    3.74            298
#
#    playtime                                               tags  \
# 0         3  ['Singleplayer', 'Для одного игрока', 'Экшен',...
# 1         3  ['Singleplayer', 'Для одного игрока', 'Экшен',...
# 2         3  ['Singleplayer', 'Для одного игрока', 'Экшен',...
# 3         4  ['gameplay feature: multiple endings', 'playst...
# 4         4  ['gameplay feature: multiple endings', 'playst...
# 5         4  ['gameplay feature: multiple endings', 'playst...
# 6         1  ['Singleplayer', 'Для одного игрока', 'Atmosph...
# 7         1  ['Singleplayer', 'Multiplayer', 'Steam Cloud',...
# 8         1  ['Singleplayer', 'Для одного игрока', 'Экшен',...
# 9         1  ['Singleplayer', 'Для одного игрока', 'Экшен',...
#
#               clean_name Platform     Genre           Publisher  NA_Sales  \
# 0               halflife       PC   Shooter       Vivendi Games      4.03
# 1               halflife      PS2   Shooter       Vivendi Games      0.29
# 2  oddworld abes oddysee       PS  Platform      GT Interactive      0.75
# 3          resident evil       PS    Action  Virgin Interactive      2.05
# 4          resident evil      SAT    Action              Capcom      0.00
# 5          resident evil      PS3    Action              Capcom      0.00
# 6       xcom ufo defense       PS  Strategy          Microprose      0.05
# 7                  quake      N64   Shooter      GT Interactive      0.15
# 8         tomb raider ii       PS    Action   Eidos Interactive      2.30
# 9         tomb raider ii       PC    Action   Eidos Interactive      0.91
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      0.00      0.09         0.00          4.12
# 1      0.23      0.00         0.08          0.60
# 2      0.44      0.00         0.06          1.24
# 3      1.16      1.11         0.73          5.05
# 4      0.00      0.17         0.00          0.17
# 5      0.00      0.12         0.00          0.12
# 6      0.04      0.00         0.01          0.09
# 7      0.04      0.00         0.00          0.19
# 8      2.46      0.20         0.28          5.24
# 9      1.25      0.00         0.13          2.29

# %% [markdown]
# **Now, we have a merged_data.csv that is merged from raw_rawg.csv and vgsales.csv. The two datasets are merged on clean_title using inner join. We have 10227 rows of games and 21 columns of features.**

# %% [markdown]
# # 2. Merge the third dataset to the first two merged dataset

# %%
df_steam = pd.read_csv("steam.csv")
df_steam.head()
# Out:
#    appid                       name release_date  english         developer  \
# 0     10             Counter-Strike   2000-11-01        1             Valve
# 1     20      Team Fortress Classic   1999-04-01        1             Valve
# 2     30              Day of Defeat   2003-05-01        1             Valve
# 3     40         Deathmatch Classic   2001-06-01        1             Valve
# 4     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software
#
#   publisher          platforms  required_age  \
# 0     Valve  windows;mac;linux             0
# 1     Valve  windows;mac;linux             0
# 2     Valve  windows;mac;linux             0
# 3     Valve  windows;mac;linux             0
# 4     Valve  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2              Multi-player;Valve Anti-Cheat enabled  Action
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 0        Action;FPS;Multiplayer             0            124534
# 1        Action;FPS;Multiplayer             0              3318
# 2  FPS;World War II;Multiplayer             0              3416
# 3        Action;FPS;Multiplayer             0              1273
# 4             FPS;Action;Sci-fi             0              5250
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 0              3339             17612              317  10000000-20000000
# 1               633               277               62   5000000-10000000
# 2               398               187               34   5000000-10000000
# 3               267               258              184   5000000-10000000
# 4               288               624              415   5000000-10000000
#
#    price
# 0   7.19
# 1   3.99
# 2   3.99
# 3   3.99
# 4   3.99

# %%
df_steam.shape
# Out:
# (27075, 18)

# %%
df_steam["clean_name"] = df_steam["name"].apply(clean_title)

# %%
df_final = pd.merge(
    df_merged,
    df_steam,
    on="clean_name",  
    how="left"    # left join
)

df_final.shape
# Out:
# (10237, 34)

# %%
df_final.head()
# Out:
#                     name_x    released  metacritic  rating  ratings_count  \
# 0                Half-Life  1998-11-19        96.0    4.37           2353
# 1                Half-Life  1998-11-19        96.0    4.37           2353
# 2  Oddworld: Abe's Oddysee  1997-09-19        85.0    3.53            555
# 3            Resident Evil  1996-03-22        91.0    4.18            788
# 4            Resident Evil  1996-03-22        91.0    4.18            788
#
#    playtime                                               tags  \
# 0         3  ['Singleplayer', 'Для одного игрока', 'Экшен',...
# 1         3  ['Singleplayer', 'Для одного игрока', 'Экшен',...
# 2         3  ['Singleplayer', 'Для одного игрока', 'Экшен',...
# 3         4  ['gameplay feature: multiple endings', 'playst...
# 4         4  ['gameplay feature: multiple endings', 'playst...
#
#               clean_name Platform     Genre           Publisher  NA_Sales  \
# 0               halflife       PC   Shooter       Vivendi Games      4.03
# 1               halflife      PS2   Shooter       Vivendi Games      0.29
# 2  oddworld abes oddysee       PS  Platform      GT Interactive      0.75
# 3          resident evil       PS    Action  Virgin Interactive      2.05
# 4          resident evil      SAT    Action              Capcom      0.00
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales    appid  \
# 0      0.00      0.09         0.00          4.12     70.0
# 1      0.23      0.00         0.08          0.60     70.0
# 2      0.44      0.00         0.06          1.24  15700.0
# 3      1.16      1.11         0.73          5.05      NaN
# 4      0.00      0.17         0.00          0.17      NaN
#
#                        name release_date  english             developer  \
# 0                 Half-Life   1998-11-08      1.0                 Valve
# 1                 Half-Life   1998-11-08      1.0                 Valve
# 2  Oddworld: Abe's Oddysee®   2008-08-28      1.0  Oddworld Inhabitants
# 3                       NaN          NaN      NaN                   NaN
# 4                       NaN          NaN      NaN                   NaN
#
#               publisher          platforms  required_age  \
# 0                 Valve  windows;mac;linux           0.0
# 1                 Valve  windows;mac;linux           0.0
# 2  Oddworld Inhabitants            windows           0.0
# 3                   NaN                NaN           NaN
# 4                   NaN                NaN           NaN
#
#                                           categories     genres  \
# 0  Single-player;Multi-player;Online Multi-Player...     Action
# 1  Single-player;Multi-player;Online Multi-Player...     Action
# 2                  Single-player;Steam Trading Cards  Adventure
# 3                                                NaN        NaN
# 4                                                NaN        NaN
#
#                   steamspy_tags  achievements  positive_ratings  \
# 0            FPS;Classic;Action           0.0           27755.0
# 1            FPS;Classic;Action           0.0           27755.0
# 2  Adventure;Platformer;Classic           0.0            2739.0
# 3                           NaN           NaN               NaN
# 4                           NaN           NaN               NaN
#
#    negative_ratings  average_playtime  median_playtime            owners  \
# 0            1100.0            1300.0             83.0  5000000-10000000
# 1            1100.0            1300.0             83.0  5000000-10000000
# 2             442.0             387.0            217.0   2000000-5000000
# 3               NaN               NaN              NaN               NaN
# 4               NaN               NaN              NaN               NaN
#
#    price
# 0   7.19
# 1   7.19
# 2   1.99
# 3    NaN
# 4    NaN

# %%
df_final.drop(columns=['release_date', 'name', 'platforms', 'developer', 'publisher', 'appid', 'tags', 'clean_name', 'english', 'genres', 'owners', 'steamspy_tags'], inplace=True)  # if game_name is your unified name

df_final.rename(columns={'name_x': 'name', 'NA_Sales': 'NA_Sales(MM)', 'EU_Sales': 'EU_Sales(MM)', 'JP_Sales': 'JP_Sales(MM)', 'Other_Sales': 'Other_Sales(MM)', 'Global_Sales': 'Global_Sales(MM)'}, inplace=True)

print(df_final.isnull().sum())

print(df_final.describe(include='all'))
# Out:
# name                   0
# released              39
# metacritic          5836
# rating                 0
# ratings_count          0
# playtime               0
# Platform               0
# Genre                  0
# Publisher             15
# NA_Sales(MM)           0
# EU_Sales(MM)           0
# JP_Sales(MM)           0
# Other_Sales(MM)        0
# Global_Sales(MM)       0
# required_age        8701
# categories          8701
# achievements        8701
# positive_ratings    8701
# negative_ratings    8701
# average_playtime    8701
# median_playtime     8701
# price               8701
# dtype: int64
#                                name    released   metacritic        rating  \
# count                         10237       10198  4401.000000  10237.000000
# unique                         6057        2923          NaN           NaN
# top     Need For Speed: Most Wanted  2011-11-15          NaN           NaN
# freq                             12          45          NaN           NaN
# mean                            NaN         NaN    72.896387      2.165299
# std                             NaN         NaN    12.674408      1.848361
# min                             NaN         NaN    23.000000      0.000000
# 25%                             NaN         NaN    65.000000      0.000000
# 50%                             NaN         NaN    75.000000      3.120000
# 75%                             NaN         NaN    82.000000      3.830000
# max                             NaN         NaN    99.000000      4.830000
#
#         ratings_count      playtime Platform   Genre        Publisher  \
# count    10237.000000  10237.000000    10237   10237            10222
# unique            NaN           NaN       28      12              379
# top               NaN           NaN      PS2  Action  Electronic Arts
# freq              NaN           NaN     1306    2249             1107
# mean       163.197616      3.402462      NaN     NaN              NaN
# std        490.292438     12.569649      NaN     NaN              NaN
# min          0.000000      0.000000      NaN     NaN              NaN
# 25%          2.000000      0.000000      NaN     NaN              NaN
# 50%         11.000000      0.000000      NaN     NaN              NaN
# 75%         72.000000      2.000000      NaN     NaN              NaN
# max       7058.000000    239.000000      NaN     NaN              NaN
#
#         NA_Sales(MM)  EU_Sales(MM)  JP_Sales(MM)  Other_Sales(MM)  \
# count   10237.000000  10237.000000  10237.000000     10237.000000
# unique           NaN           NaN           NaN              NaN
# top              NaN           NaN           NaN              NaN
# freq             NaN           NaN           NaN              NaN
# mean        0.351399      0.194752      0.071203         0.065840
# std         0.939937      0.588812      0.300207         0.227991
# min         0.000000      0.000000      0.000000         0.000000
# 25%         0.040000      0.010000      0.000000         0.000000
# 50%         0.130000      0.040000      0.000000         0.020000
# 75%         0.340000      0.170000      0.010000         0.050000
# max        41.490000     29.020000      6.810000        10.570000
#
#         Global_Sales(MM)  required_age     categories  achievements  \
# count       10237.000000   1536.000000           1536   1536.000000
# unique               NaN           NaN            248           NaN
# top                  NaN           NaN  Single-player           NaN
# freq                 NaN           NaN            296           NaN
# mean            0.683407      3.678385            NaN     31.231771
# std             1.790607      7.021749            NaN     76.369108
# min             0.010000      0.000000            NaN      0.000000
# 25%             0.090000      0.000000            NaN      0.000000
# 50%             0.240000      0.000000            NaN      7.500000
# 75%             0.640000      0.000000            NaN     50.000000
# max            82.740000     18.000000            NaN   1130.000000
#
#         positive_ratings  negative_ratings  average_playtime  median_playtime  \
# count        1536.000000       1536.000000       1536.000000      1536.000000
# unique               NaN               NaN               NaN              NaN
# top                  NaN               NaN               NaN              NaN
# freq                 NaN               NaN               NaN              NaN
# mean        13236.734375       2201.501953        770.578776       593.511068
# std         41417.891481       9537.478681       1599.728866      1144.379496
# min             0.000000          0.000000          0.000000         0.000000
# 25%           353.500000         93.000000          7.000000         8.000000
# 50%          1599.000000        334.500000        266.000000       259.000000
# 75%          8344.750000       1353.500000        759.000000       680.000000
# max        329061.000000     139308.000000      27375.000000     27375.000000
#
#               price
# count   1536.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean      14.124277
# std        9.627936
# min        0.000000
# 25%        6.990000
# 50%       11.990000
# 75%       19.115000
# max       49.990000

# %%
df_final = df_final.dropna(subset=['released', 'Publisher', 'metacritic'])

print(df_final.isnull().sum())
# Out:
# name                   0
# released               0
# metacritic             0
# rating                 0
# ratings_count          0
# playtime               0
# Platform               0
# Genre                  0
# Publisher              0
# NA_Sales(MM)           0
# EU_Sales(MM)           0
# JP_Sales(MM)           0
# Other_Sales(MM)        0
# Global_Sales(MM)       0
# required_age        3132
# categories          3132
# achievements        3132
# positive_ratings    3132
# negative_ratings    3132
# average_playtime    3132
# median_playtime     3132
# price               3132
# dtype: int64

# %%
df_final.head(10)
# Out:
#                          name    released  metacritic  rating  ratings_count  \
# 0                   Half-Life  1998-11-19        96.0    4.37           2353
# 1                   Half-Life  1998-11-19        96.0    4.37           2353
# 2     Oddworld: Abe's Oddysee  1997-09-19        85.0    3.53            555
# 3               Resident Evil  1996-03-22        91.0    4.18            788
# 4               Resident Evil  1996-03-22        91.0    4.18            788
# 5               Resident Evil  1996-03-22        91.0    4.18            788
# 7                       Quake  1996-06-22        94.0    4.25            474
# 8              Tomb Raider II  1997-10-31        69.0    3.74            298
# 9              Tomb Raider II  1997-10-31        69.0    3.74            298
# 19  Crash Bandicoot 3: Warped  1998-10-31        91.0    4.34            641
#
#     playtime Platform     Genre                    Publisher  NA_Sales(MM)  \
# 0          3       PC   Shooter                Vivendi Games          4.03
# 1          3      PS2   Shooter                Vivendi Games          0.29
# 2          3       PS  Platform               GT Interactive          0.75
# 3          4       PS    Action           Virgin Interactive          2.05
# 4          4      SAT    Action                       Capcom          0.00
# 5          4      PS3    Action                       Capcom          0.00
# 7          1      N64   Shooter               GT Interactive          0.15
# 8          1       PS    Action            Eidos Interactive          2.30
# 9          1       PC    Action            Eidos Interactive          0.91
# 19         5       PS  Platform  Sony Computer Entertainment          3.68
#
#     EU_Sales(MM)  JP_Sales(MM)  Other_Sales(MM)  Global_Sales(MM)  \
# 0           0.00          0.09             0.00              4.12
# 1           0.23          0.00             0.08              0.60
# 2           0.44          0.00             0.06              1.24
# 3           1.16          1.11             0.73              5.05
# 4           0.00          0.17             0.00              0.17
# 5           0.00          0.12             0.00              0.12
# 7           0.04          0.00             0.00              0.19
# 8           2.46          0.20             0.28              5.24
# 9           1.25          0.00             0.13              2.29
# 19          1.75          1.42             0.28              7.13
#
#     required_age                                         categories  \
# 0            0.0  Single-player;Multi-player;Online Multi-Player...
# 1            0.0  Single-player;Multi-player;Online Multi-Player...
# 2            0.0                  Single-player;Steam Trading Cards
# 3            NaN                                                NaN
# 4            NaN                                                NaN
# 5            NaN                                                NaN
# 7            0.0       Single-player;Multi-player;Co-op;Steam Cloud
# 8           12.0                                      Single-player
# 9           12.0                                      Single-player
# 19           NaN                                                NaN
#
#     achievements  positive_ratings  negative_ratings  average_playtime  \
# 0            0.0           27755.0            1100.0            1300.0
# 1            0.0           27755.0            1100.0            1300.0
# 2            0.0            2739.0             442.0             387.0
# 3            NaN               NaN               NaN               NaN
# 4            NaN               NaN               NaN               NaN
# 5            NaN               NaN               NaN               NaN
# 7            0.0            2618.0             136.0             167.0
# 8            0.0             805.0             115.0               3.0
# 9            0.0             805.0             115.0               3.0
# 19           NaN               NaN               NaN               NaN
#
#     median_playtime  price
# 0              83.0   7.19
# 1              83.0   7.19
# 2             217.0   1.99
# 3               NaN    NaN
# 4               NaN    NaN
# 5               NaN    NaN
# 7             189.0   3.99
# 8               3.0   4.99
# 9               3.0   4.99
# 19              NaN    NaN

# %%
df_final.columns
# Out:
# Index(['name', 'released', 'metacritic', 'rating', 'ratings_count', 'playtime',
#        'Platform', 'Genre', 'Publisher', 'NA_Sales(MM)', 'EU_Sales(MM)',
#        'JP_Sales(MM)', 'Other_Sales(MM)', 'Global_Sales(MM)', 'required_age',
#        'categories', 'achievements', 'positive_ratings', 'negative_ratings',
#        'average_playtime', 'median_playtime', 'price'],
#       dtype='object')

# %%
# Drop useless columns 
df_final.drop(columns=['required_age',
       'categories', 'achievements', 'positive_ratings', 'negative_ratings',
       'average_playtime', 'median_playtime'], inplace=True)


# df_final['has_rating'] = df_final['ratings_count'] > 0

print(df_final.isnull().sum())
# Out:
# name                   0
# released               0
# metacritic             0
# rating                 0
# ratings_count          0
# playtime               0
# Platform               0
# Genre                  0
# Publisher              0
# NA_Sales(MM)           0
# EU_Sales(MM)           0
# JP_Sales(MM)           0
# Other_Sales(MM)        0
# Global_Sales(MM)       0
# price               3132
# dtype: int64

# %%
df_final.shape
# Out:
# (4388, 15)

# %% [markdown]
# Add Platform Mapping

# %%
#define groupings
platform_group_map = {
    'PS': 'PlayStation Consoles', 'PS2': 'PlayStation Consoles', 'PS3': 'PlayStation Consoles', 'PS4': 'PlayStation Consoles',
    'XB': 'Xbox Consoles', 'X360': 'Xbox Consoles', 'XOne': 'Xbox Consoles',
    'NES': 'Nintendo Consoles', 'SNES': 'Nintendo Consoles', 'N64': 'Nintendo Consoles', 'GC': 'Nintendo Consoles',
    'Wii': 'Wii Series', 'WiiU': 'Wii Series',
    'PSP': 'Handhelds', 'PSV': 'Handhelds', 'GB': 'Handhelds', 'GBA': 'Handhelds', 'DS': 'Handhelds', '3DS': 'Handhelds', 'WS': 'Handhelds',
    'PC': 'PC',
    'GEN': 'Other', 'SAT': 'Other', 'DC': 'Other', 'SCD': 'Other', '3DO': 'Other', 'NG': 'Other', '2600': 'Other'
}

#map platforms to groups
df_final['Platform_Group'] = df_final['Platform'].map(platform_group_map)
df_final['Platform_Group'].value_counts()
# Out:
# Platform_Group
# PlayStation Consoles    1436
# Xbox Consoles            967
# Handhelds                847
# PC                       575
# Wii Series               306
# Nintendo Consoles        233
# Other                     24
# Name: count, dtype: int64

# %%
print(df_final.duplicated().sum())
# Out:
# 4

# %%
df_final.drop_duplicates(inplace=True)
print(df_final.duplicated().sum())
# Out:
# 0

# %%
df_final.to_csv("final_dataset.csv", index=False, encoding="utf-8")

# %%
df_final.name.nunique()
# Out:
# 2217

# %% [markdown]
# **At the end, we have a final_dataset.csv that is merged from merged_data.csv and steam.csv. The two datasets are merged on clean_title using left join where all the rows are kept from the merged_data.csv dataset even though they are not a common game in both dataset. This is because there are only ~1500 games in common from the two datasets. In order to keep as much data as possible, We had to use left join. We end up having 4388 rows of games and 17 columns of features.**
